# %% [markdown]
# # 📘 Deep Learning Text Generation Learning Project
# ## Text Generation using **Vanilla RNN, LSTM, and GRU**
#
# This notebook is built for **students and beginners** to understand how sequence models learn:
# - grammar
# - sentence flow
# - contextual dependencies
# - next-word prediction
# - text generation
#
# 🎯 **Goal:** Compare **Simple RNN vs LSTM vs GRU** on the same text corpus and understand why gated architectures perform better.

# %% [markdown]
# # 🧠 Problem Statement
# Design and implement a DL model capable of learning the underlying structure, grammar, and contextual dependencies of a given text corpus to generate coherent and meaningful text sequences using:
#
# 1. **Vanilla RNN**
# 2. **LSTM**
# 3. **GRU**
#
# Then compare:
# - training loss
# - generated text quality
# - memory handling
# - long-term dependency learning

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Embedding, SimpleRNN, LSTM, GRU, Dense
import numpy as np
import matplotlib.pyplot as plt
print("TensorFlow:", tf.__version__)
# Out:
# TensorFlow: 2.20.0

# %% [markdown]
# # 📥 Load Text Corpus
# We use a **small built-in sample corpus** so students can run this quickly.
# You can later replace it with:
# - Shakespeare text
# - song lyrics
# - chatbot data
# - story paragraphs
# - custom PDF extracted text

# %%
corpus = '''
deep learning is transforming artificial intelligence
recurrent neural networks are useful for sequential data
lstm helps remember long term dependencies
gru is faster and simpler than lstm
text generation models predict the next word
deep learning models can generate meaningful sentences
'''
print(corpus)
# Out:
# deep learning is transforming artificial intelligence
# recurrent neural networks are useful for sequential data
# lstm helps remember long term dependencies
# gru is faster and simpler than lstm
# text generation models predict the next word
# deep learning models can generate meaningful sentences

# %% [markdown]
# # 🔤 Tokenization & Sequence Creation
# We convert text into integer tokens and create **n-gram style sequences**
# for next-word prediction.

# %%
tokenizer = Tokenizer()
tokenizer.fit_on_texts([corpus])

total_words = len(tokenizer.word_index) + 1
print("Vocabulary size:", total_words)

input_sequences = []
for line in corpus.split('\n'):
    token_list = tokenizer.texts_to_sequences([line])[0]
    for i in range(1, len(token_list)):
        n_gram_seq = token_list[:i+1]
        input_sequences.append(n_gram_seq)

max_len = max(len(seq) for seq in input_sequences)
input_sequences = pad_sequences(input_sequences, maxlen=max_len, padding='pre')

X = input_sequences[:, :-1]
y = input_sequences[:, -1]

print("X shape:", X.shape)
print("y shape:", y.shape)
# Out:
# Vocabulary size: 37
# X shape: (35, 7)
# y shape: (35,)

# %% [markdown]
# # 🧠 Model 1: Vanilla RNN
# This is the baseline sequential model.
# It struggles with long-term dependencies because of vanishing gradients.

# %%
rnn_model = Sequential([
    Embedding(total_words, 32, input_length=max_len-1),
    SimpleRNN(64),
    Dense(total_words, activation='softmax')
])

rnn_model.compile(loss='sparse_categorical_crossentropy',
                  optimizer='adam',
                  metrics=['accuracy'])

rnn_history = rnn_model.fit(X, y, epochs=100, verbose=0)
print("Vanilla RNN training completed")
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/embedding.py:100: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# Vanilla RNN training completed

# %% [markdown]
# # 🔒 Model 2: LSTM
# LSTM uses **input, forget, and output gates**
# to preserve long-term memory.

# %%
lstm_model = Sequential([
    Embedding(total_words, 32, input_length=max_len-1),
    LSTM(64),
    Dense(total_words, activation='softmax')
])

lstm_model.compile(loss='sparse_categorical_crossentropy',
                   optimizer='adam',
                   metrics=['accuracy'])

lstm_history = lstm_model.fit(X, y, epochs=100, verbose=0)
print("LSTM training completed")
# Out:
# LSTM training completed

# %% [markdown]
# # ⚡ Model 3: GRU
# GRU uses **reset + update gates**.
# It is computationally faster than LSTM and often gives similar results.

# %%
gru_model = Sequential([
    Embedding(total_words, 32, input_length=max_len-1),
    GRU(64),
    Dense(total_words, activation='softmax')
])

gru_model.compile(loss='sparse_categorical_crossentropy',
                  optimizer='adam',
                  metrics=['accuracy'])

gru_history = gru_model.fit(X, y, epochs=100, verbose=0)
print("GRU training completed")
# Out:
# GRU training completed

# %% [markdown]
# ## 📉 Compare Training Loss

# %%
plt.figure(figsize=(10,4))
plt.plot(rnn_history.history['loss'], label='RNN')
plt.plot(lstm_history.history['loss'], label='LSTM')
plt.plot(gru_history.history['loss'], label='GRU')
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.title("Training Loss Comparison")
plt.legend()
plt.show()

# %% [markdown]
# # ✍️ Text Generation Function
# This function predicts the next word repeatedly to generate a sentence.

# %%
def generate_text(model, seed_text, next_words=5):
    for _ in range(next_words):
        token_list = tokenizer.texts_to_sequences([seed_text])[0]
        token_list = pad_sequences([token_list], maxlen=max_len-1, padding='pre')
        predicted = np.argmax(model.predict(token_list, verbose=0), axis=-1)[0]

        output_word = ""
        for word, index in tokenizer.word_index.items():
            if index == predicted:
                output_word = word
                break
        seed_text += " " + output_word
    return seed_text

# %% [markdown]
# ## 🧪 Generate Text Samples

# %%
print("RNN :", generate_text(rnn_model, "deep learning", 5))
print("LSTM:", generate_text(lstm_model, "deep learning", 5))
print("GRU :", generate_text(gru_model, "deep learning", 5))
# Out:
# RNN : deep learning models can generate meaningful sentences
# LSTM: deep learning learning transforming artificial artificial intelligence
# GRU : deep learning is transforming artificial intelligence intelligence

# %% [markdown]
# # 📚 Student Learning Tasks
# ### ✅ Beginner Tasks
# 1. Replace corpus with your own paragraph
# 2. Increase embedding dimension
# 3. Increase epochs to 200
# 4. Change hidden units 64 → 128
# 5. Generate 10 words instead of 5

# %% [markdown]
# ## 🚀 Implementing Beginner Tasks

# %% [markdown]
# ### 📥 New Text Corpus

# %%
new_corpus = '''
the quick brown fox jumps over the lazy dog
lazy dog barks at the moon
moon shines bright in the night sky
night sky is full of stars
stars twinkle and shine brightly
'''
print(new_corpus)
# Out:
# the quick brown fox jumps over the lazy dog
# lazy dog barks at the moon
# moon shines bright in the night sky
# night sky is full of stars
# stars twinkle and shine brightly

# %% [markdown]
# ### 🔤 Tokenization & Sequence Creation (with New Corpus)

# %%
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Embedding, SimpleRNN, LSTM, GRU, Dense
import numpy as np
import matplotlib.pyplot as plt

tokenizer_new = Tokenizer()
tokenizer_new.fit_on_texts([new_corpus])

total_words_new = len(tokenizer_new.word_index) + 1
print("New Vocabulary size:", total_words_new)

input_sequences_new = []
for line in new_corpus.split('\n'):
    token_list_new = tokenizer_new.texts_to_sequences([line])[0]
    for i in range(1, len(token_list_new)):
        n_gram_seq_new = token_list_new[:i+1]
        input_sequences_new.append(n_gram_seq_new)

max_len_new = max(len(seq) for seq in input_sequences_new)
input_sequences_new = pad_sequences(input_sequences_new, maxlen=max_len_new, padding='pre')

X_new = input_sequences_new[:, :-1]
y_new = input_sequences_new[:, -1]

print("X_new shape:", X_new.shape)
print("y_new shape:", y_new.shape)
# Out:
# New Vocabulary size: 25
# X_new shape: (28, 8)
# y_new shape: (28,)

# %% [markdown]
# ### ⚙️ New Model Parameters

# %%
embedding_dim_new = 128  # Increased from 32
epochs_new = 200         # Increased from 100
hidden_units_new = 128   # Increased from 64
next_words_new = 10      # Increased from 5

print(f"New Embedding Dimension: {embedding_dim_new}")
print(f"New Number of Epochs: {epochs_new}")
print(f"New Hidden Units: {hidden_units_new}")
print(f"New Words to Generate: {next_words_new}")
# Out:
# New Embedding Dimension: 128
# New Number of Epochs: 200
# New Hidden Units: 128
# New Words to Generate: 10

# %% [markdown]
# ### 🧠 Model 1: Vanilla RNN (with New Parameters)

# %%
rnn_model_new = Sequential([
    Embedding(total_words_new, embedding_dim_new, input_length=max_len_new-1),
    SimpleRNN(hidden_units_new),
    Dense(total_words_new, activation='softmax')
])

rnn_model_new.compile(loss='sparse_categorical_crossentropy',
                      optimizer='adam',
                      metrics=['accuracy'])

rnn_history_new = rnn_model_new.fit(X_new, y_new, epochs=epochs_new, verbose=0)
print("Vanilla RNN training with new parameters completed")
# Out:
# Vanilla RNN training with new parameters completed

# %% [markdown]
# ### 🔒 Model 2: LSTM (with New Parameters)

# %%
lstm_model_new = Sequential([
    Embedding(total_words_new, embedding_dim_new, input_length=max_len_new-1),
    LSTM(hidden_units_new),
    Dense(total_words_new, activation='softmax')
])

lstm_model_new.compile(loss='sparse_categorical_crossentropy',
                       optimizer='adam',
                       metrics=['accuracy'])

lstm_history_new = lstm_model_new.fit(X_new, y_new, epochs=epochs_new, verbose=0)
print("LSTM training with new parameters completed")
# Out:
# LSTM training with new parameters completed

# %% [markdown]
# ### ⚡ Model 3: GRU (with New Parameters)

# %%
gru_model_new = Sequential([
    Embedding(total_words_new, embedding_dim_new, input_length=max_len_new-1),
    GRU(hidden_units_new),
    Dense(total_words_new, activation='softmax')
])

gru_model_new.compile(loss='sparse_categorical_crossentropy',
                   optimizer='adam',
                   metrics=['accuracy'])

gru_history_new = gru_model_new.fit(X_new, y_new, epochs=epochs_new, verbose=0)
print("GRU training with new parameters completed")
# Out:
# GRU training with new parameters completed

# %% [markdown]
# ### 📉 Compare Training Loss (New Models)

# %%
plt.figure(figsize=(10,4))
plt.plot(rnn_history_new.history['loss'], label='RNN (New)')
plt.plot(lstm_history_new.history['loss'], label='LSTM (New)')
plt.plot(gru_history_new.history['loss'], label='GRU (New)')
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.title("Training Loss Comparison (New Parameters)")
plt.legend()
plt.show()

# %% [markdown]
# ### ✍️ Text Generation Function (adapted for new tokenizer and max_len)

# %%
def generate_text_new(model, seed_text, next_words, tokenizer_obj, max_sequence_length):
    for _ in range(next_words):
        token_list = tokenizer_obj.texts_to_sequences([seed_text])[0]
        token_list = pad_sequences([token_list], maxlen=max_sequence_length-1, padding='pre')
        predicted = np.argmax(model.predict(token_list, verbose=0), axis=-1)[0]

        output_word = ""
        for word, index in tokenizer_obj.word_index.items():
            if index == predicted:
                output_word = word
                break
        seed_text += " " + output_word
    return seed_text

# %% [markdown]
# ### 🧪 Generate Text Samples (New Models)

# %%
print("RNN (New) :", generate_text_new(rnn_model_new, "the quick", next_words_new, tokenizer_new, max_len_new))
print("LSTM (New):", generate_text_new(lstm_model_new, "the quick", next_words_new, tokenizer_new, max_len_new))
print("GRU (New) :", generate_text_new(gru_model_new, "the quick", next_words_new, tokenizer_new, max_len_new))
# Out:
# RNN (New) : the quick brown fox jumps over the lazy dog barks at the
# LSTM (New): the quick brown fox jumps over the lazy dog dog dog the
# GRU (New) : the quick brown fox jumps over the lazy dog dog barks at

# %% [markdown]
# # ✅ Conclusion
# - **Vanilla RNN** learns short patterns but struggles with memory
# - **LSTM** captures long-range grammar dependencies better
# - **GRU** gives similar performance with fewer gates and faster training
# - This notebook helps students understand **sequence modeling mathematically and practically**
